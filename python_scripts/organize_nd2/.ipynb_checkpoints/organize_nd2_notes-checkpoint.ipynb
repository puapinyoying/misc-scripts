# %% [markdown]
# # Making a script to organize high-throughput imaging data
#
# - Generates folders for each drug and dose
# - Rename .nd2 files to remove spaces and commas
# - Moves the .nd2 files into organized drug, dose folders
#
# By Prech Uapinyoying
#
# 12/20/2018

# %%
import shutil
import os # for dealing with operating system commands like paths to files
#import sys
import re
import itertools

# %% [markdown]
# # Step 1. Generate test files
#
# Before you even start, you need to create some test files to play with. Use the included 'create_orig_files.sh'
#
# Then run the script in the directory you want by doing `bash create_orig_files.sh`
#
# ---

# %% [markdown]
# # Step2.  Get the current directory path and a list of all the files in it

# %%
# Get the current working directory
cwd = os.getcwd()
cwd
# Out:
# '/Users/uapinyoyingpb/misc-scripts/python_scripts/organize_nd2'

# %%
# I generated the test files into a folder called 'test_files' lets create that path
# join command will intellegently combine path names with correct slash for any operating system
filesDir = os.path.join(cwd, 'test_files') 
filesDir
# Out:
# '/Users/uapinyoyingpb/misc-scripts/python_scripts/organize_nd2/test_files'

# %%
# Get a list of files in that test_files directory
fileList = os.listdir(filesDir)
fileList[0:5] # take a look at first 5
# Out:
# ['grn_d6_24hr_posttx_WellB24_Channel405 nm,488 nm,561 nm,640 nm_Seq0024.nd2',
#  'grn_d6_24hr_posttx_WellF03_Channel405 nm,488 nm,561 nm,640 nm_Seq0141.nd2',
#  'grn_d6_24hr_posttx_WellA22_Channel405 nm,488 nm,561 nm,640 nm_Seq0021.nd2',
#  'grn_d6_24hr_posttx_WellJ20_Channel405 nm,488 nm,561 nm,640 nm_Seq0220.nd2',
#  'grn_d6_24hr_posttx_WellI01_Channel405 nm,488 nm,561 nm,640 nm_Seq0192.nd2']

# %%
# We need to check if the filename also ends with an nd2, can do this with os.path.splitext
filename, file_extension = os.path.splitext(
    'grn_d6_24hr_posttx_WellB24_Channel405 nm,488 nm,561 nm,640 nm_Seq0024.nd2')

print(f'The extension is: "{file_extension}"')
# Out:
# The extension is: ".nd2"

# %%
# Make it into a function, you will probably use the script in the folder anyways

def get_nd2_fileList(filesDir):
    
    fileList = []
    
    cwd = os.getcwd()
    allFiles = os.listdir(filesDir)
    for file in allFiles:
        filename, file_extension = os.path.splitext(file)
        if file_extension == '.nd2':
            fileList.append(file)
    
    return fileList

# %% [markdown]
# ---
#
#
# # Step 3. Automating the generation of new drug/dose directories

# %%
#  lets make 8 drug directories
drugDirNames = ['drug1','drug2','drug3','drug4','drug5','drug6',
                'drug7','drug8','drug9','drug10','drug11', 'drug12']
drugDirNames
# Out:
# ['drug1',
#  'drug2',
#  'drug3',
#  'drug4',
#  'drug5',
#  'drug6',
#  'drug7',
#  'drug8',
#  'drug9',
#  'drug10',
#  'drug11',
#  'drug12']

# %%
doseDirNames = ['dose1','dose2','dose3','dose4','dose5','dose6','dose7','dose8']
doseDirNames
# Out:
# ['dose1', 'dose2', 'dose3', 'dose4', 'dose5', 'dose6', 'dose7', 'dose8']

# %%
# Lets add the full path to the first drug folder and drug dose
os.path.join(filesDir, drugDirNames[0], doseDirNames[0])
# Out:
# '/Users/uapinyoyingpb/misc-scripts/python_scripts/organize_nd2/test_files/drug1/dose1'

# %%
# Ok, now lets make a for loop that will generate all these paths for us and put it into a list

fullDrugDirPaths = [] # make an empty list to put the generated directory paths into

# For each drug directory in the list, join the paths and add it to the empty list
for drugDir in drugDirNames:
    for doseDir in doseDirNames:
        currDir = os.path.join(filesDir, drugDir, doseDir)
        fullDrugDirPaths.append(currDir)
    
fullDrugDirPaths[0:16]
# Out:
# ['/Users/uapinyoyingpb/misc-scripts/python_scripts/organize_nd2/test_files/drug1/dose1',
#  '/Users/uapinyoyingpb/misc-scripts/python_scripts/organize_nd2/test_files/drug1/dose2',
#  '/Users/uapinyoyingpb/misc-scripts/python_scripts/organize_nd2/test_files/drug1/dose3',
#  '/Users/uapinyoyingpb/misc-scripts/python_scripts/organize_nd2/test_files/drug1/dose4',
#  '/Users/uapinyoyingpb/misc-scripts/python_scripts/organize_nd2/test_files/drug1/dose5',
#  '/Users/uapinyoyingpb/misc-scripts/python_scripts/organize_nd2/test_files/drug1/dose6',
#  '/Users/uapinyoyingpb/misc-scripts/python_scripts/organize_nd2/test_files/drug1/dose7',
#  '/Users/uapinyoyingpb/misc-scripts/python_scripts/organize_nd2/test_files/drug1/dose8',
#  '/Users/uapinyoyingpb/misc-scripts/python_scripts/organize_nd2/test_files/drug2/dose1',
#  '/Users/uapinyoyingpb/misc-scripts/python_scripts/organize_nd2/test_files/drug2/dose2',
#  '/Users/uapinyoyingpb/misc-scripts/python_scripts/organize_nd2/test_files/drug2/dose3',
#  '/Users/uapinyoyingpb/misc-scripts/python_scripts/organize_nd2/test_files/drug2/dose4',
#  '/Users/uapinyoyingpb/misc-scripts/python_scripts/organize_nd2/test_files/drug2/dose5',
#  '/Users/uapinyoyingpb/misc-scripts/python_scripts/organize_nd2/test_files/drug2/dose6',
#  '/Users/uapinyoyingpb/misc-scripts/python_scripts/organize_nd2/test_files/drug2/dose7',
#  '/Users/uapinyoyingpb/misc-scripts/python_scripts/organize_nd2/test_files/drug2/dose8']

# %%
# make this into a function

def gen_dir_paths(drugDirNames, drugDoseNames, filesDir):
    fullDrugDirPaths = [] # make an empty list to put the generated directory paths into

    # For each drug directory in the list, join the paths and add it to the empty list
    for drugDir in drugDirNames:
        for doseDir in doseDirNames:
            currDir = os.path.join(filesDir, drugDir, doseDir)
            fullDrugDirPaths.append(currDir)
            
    return fullDrugDirPaths

# %%
# Lets make a new directory, we only want to make the new directory if it doesn't exist yet
# again, lets try it with the first folder only
# if not os.path.exists(fullDrugDirPaths[1]):
#     os.makedirs(fullDrugDirPaths[1])
#     print('I just created this folder: {}'.format(fullDrugDirPaths[1]))
# else:
#     print('Folder already exists, man!')

# %%
def make_dirs(fullDrugDirPaths):
    for path in fullDrugDirPaths:
        try:
            # chng to 'exist_ok=False' if you don't want to allow overwriting
            os.makedirs(path, exist_ok=True) 
            #print(f'Created directory: {path}')
        except FileExistsError:
            print(f'Error: {path} exists dude. Have you already run this script before?')

# %%
# Now actually make all the directories
make_dirs(fullDrugDirPaths)

# %%
# Check if the folders are there
next(os.walk(filesDir))[1]
# Out:
# ['drug12',
#  'drug8',
#  'drug6',
#  'drug1',
#  'drug7',
#  'drug9',
#  'drug11',
#  'drug10',
#  'drug2',
#  'drug5',
#  'drug4',
#  'drug3']

# %% [markdown]
# ---
#
# # Step 4. Figure out how to rename files to remove spaces and commas
#
# First, lets try to use regular expressions to determine what well each file is from based on its name

# %%
REGEXP = r'(\w+)_Well(\w+)_Channel(\d+) nm,(\d+) nm,(\d+) nm,(\d+) nm_(\w+).(nd2)'

test = 'grn_d6_24hr_posttx_WellA01_Channel405 nm,488 nm,561 nm,640 nm_Seq0024.nd2'

r = re.search(REGEXP,test)

# This (f'{}') is a special technique for building strings called 'f-string interpolation'
# Look it up, its super useful
replacement = f'{r.group(1)}_Well{r.group(2)}_Channel_{r.group(3)}nm_\
{r.group(4)}nm_{r.group(5)}nm_{r.group(6)}nm_{r.group(7)}.{r.group(8)}'

print(test) # The original file name in our test case (spaces, commas and all)
# Out:
# grn_d6_24hr_posttx_WellA01_Channel405 nm,488 nm,561 nm,640 nm_Seq0024.nd2

# %%
replacement # Check the replacement string if it removed all our spaces and commas
# Out:
# 'grn_d6_24hr_posttx_WellA01_Channel_405nm_488nm_561nm_640nm_Seq0024.nd2'

# %%
# Quick test if renaming works
#shutil.move(os.path.join(filesDir,test),os.path.join(filesDir,replacement))

# %%
# renaming all the files using a for loop. If you do this you will need to recreate the files using the
# bash script 'create_orig_files.sh'

# for file in fileList:
#     r = re.search(REGEXP,file)
#     replacement = f'{r.group(1)}_Well{r.group(2)}_Channel_{r.group(3)}nm_\
# {r.group(4)}nm_{r.group(5)}nm_{r.group(6)}nm_{r.group(7)}.{r.group(8)}'
    
#     sourcePath = os.path.join(filesDir,file)
#     replacementPath = os.path.join(filesDir, replacement)
    
#     shutil.move(sourcePath,replacementPath)

# %% [markdown]
# Lets reserve the actual renaming for later down the line. We will try to combine renaming and moving in a single step, but first, create the name changing portion into a function that we can reuse it later

# %%
def get_new_filenames(fileList):
    # file names in a list of tuples (old name, new name)
    
    oldNewFilenameList = []
    
    for oldFilename in fileList:
        r = re.search(REGEXP,oldFilename)
        newFilename = f'{r.group(1)}_Well{r.group(2)}_Channel_{r.group(3)}nm_{r.group(4)}nm_{r.group(5)}nm_{r.group(6)}nm_{r.group(7)}.{r.group(8)}'
        oldNewFilenameList.append((oldFilename, newFilename))

    return oldNewFilenameList

# %%
# Lets get the old and new file name list

oldNewFilenameList = get_new_filenames(fileList)

# for (oldName, newName) in oldNewFilenameList:
#     print(f'old name: {oldName}')
#     print(f'new name: {newName}\n')

# %% [markdown]
# ---
#
#
# # Step 5. Matching specific files to specific directories.
#
# Now we need to figure out how to match up the file with its destination if we want to move the correct files to their new directories. We can do this by using the captured well name within the file.

# %%
# To arrange the wells for each drug, we will make a dictionary for each drug with the dose as the key 
# and list of wells as the values

drug1Dict = {'dose1': ['A01','A03','A05', 'A07'],
             'dose2': ['C01','C03','C05', 'C07'],
             'dose3': ['E01','E03','E05', 'E07'],
             'dose4': ['G01','G03','G05', 'G07'],
             'dose5': ['I01','I03','I05', 'I07'],
             'dose6': ['K01','K03','K05', 'K07'],
             'dose7': ['M01','M03','M05', 'M07'],
             'dose8': ['O01','O03','O05', 'O07']}

# We can use itertools' .items() to loop through key (dose), value (wells) pairs
for dose, wells in drug1Dict.items():
    print(dose,wells)
# Out:
# dose1 ['A01', 'A03', 'A05', 'A07']
# dose2 ['C01', 'C03', 'C05', 'C07']
# dose3 ['E01', 'E03', 'E05', 'E07']
# dose4 ['G01', 'G03', 'G05', 'G07']
# dose5 ['I01', 'I03', 'I05', 'I07']
# dose6 ['K01', 'K03', 'K05', 'K07']
# dose7 ['M01', 'M03', 'M05', 'M07']
# dose8 ['O01', 'O03', 'O05', 'O07']

# %%
# Lets try to figure out the logic for determining what file goes to what folder

# for file in fileList:
#     r = re.search(REGEXP,file)
#     for dose, wells in drug1Dict.items():
#         if r.group(2) in wells:
#             print(file,'- belongs to --> ', dose)

# %%
# Lets go a bit further and make a nested dictionary of all the drugs
# { drug: {dose: wells} }


drugDict = {'drug1': 
                 {
                  'dose1': ['A01','A03','A05', 'A07'],
                  'dose2': ['C01','C03','C05', 'C07'],
                  'dose3': ['E01','E03','E05', 'E07'],
                  'dose4': ['G01','G03','G05', 'G07'],
                  'dose5': ['I01','I03','I05', 'I07'],
                  'dose6': ['K01','K03','K05', 'K07'],
                  'dose7': ['M01','M03','M05', 'M07'],
                  'dose8': ['O01','O03','O05', 'O07']
                 },
            
            'drug2':
                 {
                  'dose1': ['A02','A04','A06', 'A08'],
                  'dose2': ['C02','C04','C06', 'C08'],
                  'dose3': ['E02','E04','E06', 'E08'],
                  'dose4': ['G02','G04','G06', 'G08'],
                  'dose5': ['I02','I04','I06', 'I08'],
                  'dose6': ['K02','K04','K06', 'K08'],
                  'dose7': ['M02','M04','M06', 'M08'],
                  'dose8': ['O02','O04','O06', 'O08']
                 },
            
            'drug3':
                {
                  'dose1': ['A09','A11','A13', 'A15'],
                  'dose2': ['C09','C11','C13', 'C15'],
                  'dose3': ['E09','E11','E13', 'E15'],
                  'dose4': ['G09','G11','G13', 'G15'],
                  'dose5': ['I09','I11','I13', 'I15'],
                  'dose6': ['K09','K11','K13', 'K15'],
                  'dose7': ['M09','M11','M13', 'M15'],
                  'dose8': ['O09','O11','O13', 'O15']
                 },
            
            'drug4':
                {
                  'dose1': ['A10','A12','A14', 'A16'],
                  'dose2': ['C10','C12','C14', 'C16'],
                  'dose3': ['E10','E12','E14', 'E16'],
                  'dose4': ['G10','G12','G14', 'G16'],
                  'dose5': ['I10','I12','I14', 'I16'],
                  'dose6': ['K10','K12','K14', 'K16'],
                  'dose7': ['M10','M12','M14', 'M16'],
                  'dose8': ['O10','O12','O14', 'O16']
                 },
            
            'drug5':
                {
                  'dose1': ['A17','A19','A21', 'A23'],
                  'dose2': ['C17','C19','C21', 'C23'],
                  'dose3': ['E17','E19','E21', 'E23'],
                  'dose4': ['G17','G19','G21', 'G23'],
                  'dose5': ['I17','I19','I21', 'I23'],
                  'dose6': ['K17','K19','K21', 'K23'],
                  'dose7': ['M17','M19','M21', 'M23'],
                  'dose8': ['O17','O19','O21', 'O23']
                 },
            'drug6':
                {
                  'dose1': ['A18','A20','A22', 'A24'],
                  'dose2': ['C18','C20','C22', 'C24'],
                  'dose3': ['E18','E20','E22', 'E24'],
                  'dose4': ['G18','G20','G22', 'G24'],
                  'dose5': ['I18','I20','I22', 'I24'],
                  'dose6': ['K18','K20','K22', 'K24'],
                  'dose7': ['M18','M20','M22', 'M24'],
                  'dose8': ['O18','O20','O22', 'O24']
                 },
            'drug7': 
                 {
                  'dose1': ['B01','B03','B05', 'B07'],
                  'dose2': ['D01','D03','D05', 'D07'],
                  'dose3': ['F01','F03','F05', 'F07'],
                  'dose4': ['H01','H03','H05', 'H07'],
                  'dose5': ['J01','J03','J05', 'J07'],
                  'dose6': ['L01','L03','L05', 'L07'],
                  'dose7': ['N01','N03','N05', 'N07'],
                  'dose8': ['P01','P03','P05', 'P07']
                 },
            
            'drug8':
                 {
                  'dose1': ['B02','B04','B06', 'B08'],
                  'dose2': ['D02','D04','D06', 'D08'],
                  'dose3': ['F02','F04','F06', 'F08'],
                  'dose4': ['H02','H04','H06', 'H08'],
                  'dose5': ['J02','J04','J06', 'J08'],
                  'dose6': ['L02','L04','L06', 'L08'],
                  'dose7': ['N02','N04','N06', 'N08'],
                  'dose8': ['P02','P04','P06', 'P08']
                 },
            
            'drug9':
                {
                  'dose1': ['B09','B11','B13', 'B15'],
                  'dose2': ['D09','D11','D13', 'D15'],
                  'dose3': ['F09','F11','F13', 'F15'],
                  'dose4': ['H09','H11','H13', 'H15'],
                  'dose5': ['J09','J11','J13', 'J15'],
                  'dose6': ['L09','L11','L13', 'L15'],
                  'dose7': ['N09','N11','N13', 'N15'],
                  'dose8': ['P09','P11','P13', 'P15']
                 },
            
            'drug10':
                {
                  'dose1': ['B10','B12','B14', 'B16'],
                  'dose2': ['D10','D12','D14', 'D16'],
                  'dose3': ['F10','F12','F14', 'F16'],
                  'dose4': ['H10','H12','H14', 'H16'],
                  'dose5': ['J10','J12','J14', 'J16'],
                  'dose6': ['L10','L12','L14', 'L16'],
                  'dose7': ['N10','N12','N14', 'N16'],
                  'dose8': ['P10','P12','P14', 'P16']
                 },
            
            'drug11':
                {
                  'dose1': ['B17','B19','B21', 'B23'],
                  'dose2': ['D17','D19','D21', 'D23'],
                  'dose3': ['F17','F19','F21', 'F23'],
                  'dose4': ['H17','H19','H21', 'H23'],
                  'dose5': ['J17','J19','J21', 'J23'],
                  'dose6': ['L17','L19','L21', 'L23'],
                  'dose7': ['N17','N19','N21', 'N23'],
                  'dose8': ['P17','P19','P21', 'P23']
                 },
            'drug12':
                {
                  'dose1': ['B18','B20','B22', 'B24'],
                  'dose2': ['D18','D20','D22', 'D24'],
                  'dose3': ['F18','F20','F22', 'F24'],
                  'dose4': ['H18','H20','H22', 'H24'],
                  'dose5': ['J18','J20','J22', 'J24'],
                  'dose6': ['L18','L20','L22', 'L24'],
                  'dose7': ['N18','N20','N22', 'N24'],
                  'dose8': ['P18','P20','P22', 'P24']
                 }
           }

# %%
# Print out everything in order

# for drug, doseList in drugDict.items():
#         for dose, wells in doseList.items():
#             print(drug, dose, wells)

# %%
# Now try matching te file with the drug and dose using the new nested dictionary data structure
# for file in fileList:
#     r = re.search(REGEXP,file)
#     for drug, doseList in drugDict.items():
#         for dose, wells in doseList.items():
#             if r.group(2) in wells:
#                 print(file,'- belongs to --> ', r.group(2), drug, dose)

# %%
# Now build upon this more to create the file path of where the file should be moved to

# Recall from above that:
# filesDir = '/Users/uapinyoyingpb/sandbox/ward_test/test_files'

fileDestList = []

for file in fileList: # original file names in a list
    r = re.search(REGEXP,file)
    for drug, doseDict in drugDict.items():
        for dose, wells in doseDict.items():
            if r.group(2) in wells:
                destPath = os.path.join(filesDir, drug, dose) # destination path
                
                # I am going to pair the file and destination path into a tuple using the extra parentheses ()
                fileDestList.append((file, destPath))

# Uncomment to see the entire list
print(fileDestList[0])


# You can access them just like a nested list
# fileDestList[0][0] <-- item 1 in the pair

#print(fileDestList[0][0],'\n\n', fileDestList[0][1])
# Out:
# ('grn_d6_24hr_posttx_WellB24_Channel405 nm,488 nm,561 nm,640 nm_Seq0024.nd2', '/Users/uapinyoyingpb/sandbox/ward_test/test_files/drug12/dose1')

# %%
# Lets create a function for it

def gen_fileDestList(filesDir, fileList, drugDict):
    fileDestList = []

    for file in fileList: # original file names in a list
        r = re.search(REGEXP,file)
        for drug, doseDict in drugDict.items():
            for dose, wells in doseDict.items():
                if r.group(2) in wells:
                    destPath = os.path.join(filesDir, drug, dose) # destination path

                    # I am going to pair the file and destination path into a tuple using the extra parentheses ()
                    fileDestList.append((file, destPath))
    
    return fileDestList

# %% [markdown]
# ---
#
# # Step 6. Putting it all together
#
# Next we want to take this list of tuples that includes the file and destination path and use it to move and rename our files at the same time, by combining what we learned earlier
#
# First thing I am going to try is take the two lists of information and pair them together to create the final list of source path + original file name and destination file path + renamed file
#
# - `fileDestList` has orginal file name paired with the destination folder
# - `oldNewFilenameList` has original filename as well paired with the new name

# %%
fileDestList[0]
# Out:
# ('grn_d6_24hr_posttx_WellB24_Channel405 nm,488 nm,561 nm,640 nm_Seq0024.nd2',
#  '/Users/uapinyoyingpb/sandbox/ward_test/test_files/drug12/dose1')

# %%
oldNewFilenameList[0]
# Out:
# ('grn_d6_24hr_posttx_WellB24_Channel405 nm,488 nm,561 nm,640 nm_Seq0024.nd2',
#  'grn_d6_24hr_posttx_WellB24_Channel_405nm_488nm_561nm_640nm_Seq0024.nd2')

# %%
# moveList = [] # a list of tuples with (originalFullFilePath, renamedNewFilePath)

# for (file, destPath) in fileDestList:
#     for (oldFile, newFile) in oldNewFilenameList:
#         if file == oldFile:
#             oldFilePath = os.path.join(filesDir, oldFile)
#             newFilePath = os.path.join(destPath, newFile)
            
#             moveList.append((oldFilePath, newFilePath))
            
# moveList[0] # peak at the first entry
# Out:
# ('/Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellB24_Channel405 nm,488 nm,561 nm,640 nm_Seq0024.nd2',
#  '/Users/uapinyoyingpb/sandbox/ward_test/test_files/drug12/dose1/grn_d6_24hr_posttx_WellB24_Channel_405nm_488nm_561nm_640nm_Seq0024.nd2')

# %%
# again, make it into a function

def gen_moveList(fileDestList, oldNewFilenameList):
    moveList = [] # a list of tuples with (originalFullFilePath, renamedNewFilePath)

    for (file, destPath) in fileDestList:
        for (oldFile, newFile) in oldNewFilenameList:
            if file == oldFile:
                oldFilePath = os.path.join(filesDir, oldFile)
                newFilePath = os.path.join(destPath, newFile)

                moveList.append((oldFilePath, newFilePath))

    return moveList

# %%
moveList = gen_moveList(fileDestList, oldNewFilenameList)
moveList[0]
# Out:
# ('/Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellB24_Channel405 nm,488 nm,561 nm,640 nm_Seq0024.nd2',
#  '/Users/uapinyoyingpb/sandbox/ward_test/test_files/drug12/dose1/grn_d6_24hr_posttx_WellB24_Channel_405nm_488nm_561nm_640nm_Seq0024.nd2')

# %%
# Finally all we have to do now is do the moving! I'll make this into a simple function

def move_files(moveList):
    for (source, destination) in moveList:
        shutil.move(source, destination)
        print(f'Moved: {source}\n\t--> {destination}')

# %%
move_files(moveList)
# Out:
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellB24_Channel405 nm,488 nm,561 nm,640 nm_Seq0024.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug12/dose1/grn_d6_24hr_posttx_WellB24_Channel_405nm_488nm_561nm_640nm_Seq0024.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellF03_Channel405 nm,488 nm,561 nm,640 nm_Seq0141.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug7/dose3/grn_d6_24hr_posttx_WellF03_Channel_405nm_488nm_561nm_640nm_Seq0141.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellA22_Channel405 nm,488 nm,561 nm,640 nm_Seq0021.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug6/dose1/grn_d6_24hr_posttx_WellA22_Channel_405nm_488nm_561nm_640nm_Seq0021.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellJ20_Channel405 nm,488 nm,561 nm,640 nm_Seq0220.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug12/dose5/grn_d6_24hr_posttx_WellJ20_Channel_405nm_488nm_561nm_640nm_Seq0220.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellI01_Channel405 nm,488 nm,561 nm,640 nm_Seq0192.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug1/dose5/grn_d6_24hr_posttx_WellI01_Channel_405nm_488nm_561nm_640nm_Seq0192.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellH16_Channel405 nm,488 nm,561 nm,640 nm_Seq0176.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug10/dose4/grn_d6_24hr_posttx_WellH16_Channel_405nm_488nm_561nm_640nm_Seq0176.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellA11_Channel405 nm,488 nm,561 nm,640 nm_Seq0010.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug3/dose1/grn_d6_24hr_posttx_WellA11_Channel_405nm_488nm_561nm_640nm_Seq0010.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellF19_Channel405 nm,488 nm,561 nm,640 nm_Seq0125.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug11/dose3/grn_d6_24hr_posttx_WellF19_Channel_405nm_488nm_561nm_640nm_Seq0125.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellB13_Channel405 nm,488 nm,561 nm,640 nm_Seq0035.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug9/dose1/grn_d6_24hr_posttx_WellB13_Channel_405nm_488nm_561nm_640nm_Seq0035.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellM20_Channel405 nm,488 nm,561 nm,640 nm_Seq0307.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug6/dose7/grn_d6_24hr_posttx_WellM20_Channel_405nm_488nm_561nm_640nm_Seq0307.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellK13_Channel405 nm,488 nm,561 nm,640 nm_Seq0252.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug3/dose6/grn_d6_24hr_posttx_WellK13_Channel_405nm_488nm_561nm_640nm_Seq0252.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellL08_Channel405 nm,488 nm,561 nm,640 nm_Seq0280.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug8/dose6/grn_d6_24hr_posttx_WellL08_Channel_405nm_488nm_561nm_640nm_Seq0280.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellF14_Channel405 nm,488 nm,561 nm,640 nm_Seq0130.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug10/dose3/grn_d6_24hr_posttx_WellF14_Channel_405nm_488nm_561nm_640nm_Seq0130.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellB16_Channel405 nm,488 nm,561 nm,640 nm_Seq0032.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug10/dose1/grn_d6_24hr_posttx_WellB16_Channel_405nm_488nm_561nm_640nm_Seq0032.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellO09_Channel405 nm,488 nm,561 nm,640 nm_Seq0344.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug3/dose8/grn_d6_24hr_posttx_WellO09_Channel_405nm_488nm_561nm_640nm_Seq0344.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellM02_Channel405 nm,488 nm,561 nm,640 nm_Seq0289.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug2/dose7/grn_d6_24hr_posttx_WellM02_Channel_405nm_488nm_561nm_640nm_Seq0289.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellH12_Channel405 nm,488 nm,561 nm,640 nm_Seq0180.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug10/dose4/grn_d6_24hr_posttx_WellH12_Channel_405nm_488nm_561nm_640nm_Seq0180.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellK16_Channel405 nm,488 nm,561 nm,640 nm_Seq0255.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug4/dose6/grn_d6_24hr_posttx_WellK16_Channel_405nm_488nm_561nm_640nm_Seq0255.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellG10_Channel405 nm,488 nm,561 nm,640 nm_Seq0153.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug4/dose4/grn_d6_24hr_posttx_WellG10_Channel_405nm_488nm_561nm_640nm_Seq0153.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellI04_Channel405 nm,488 nm,561 nm,640 nm_Seq0195.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug2/dose5/grn_d6_24hr_posttx_WellI04_Channel_405nm_488nm_561nm_640nm_Seq0195.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellF05_Channel405 nm,488 nm,561 nm,640 nm_Seq0139.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug7/dose3/grn_d6_24hr_posttx_WellF05_Channel_405nm_488nm_561nm_640nm_Seq0139.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellF23_Channel405 nm,488 nm,561 nm,640 nm_Seq0121.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug11/dose3/grn_d6_24hr_posttx_WellF23_Channel_405nm_488nm_561nm_640nm_Seq0121.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellB04_Channel405 nm,488 nm,561 nm,640 nm_Seq0044.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug8/dose1/grn_d6_24hr_posttx_WellB04_Channel_405nm_488nm_561nm_640nm_Seq0044.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellM21_Channel405 nm,488 nm,561 nm,640 nm_Seq0308.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug5/dose7/grn_d6_24hr_posttx_WellM21_Channel_405nm_488nm_561nm_640nm_Seq0308.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellH03_Channel405 nm,488 nm,561 nm,640 nm_Seq0189.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug7/dose4/grn_d6_24hr_posttx_WellH03_Channel_405nm_488nm_561nm_640nm_Seq0189.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellA01_Channel405 nm,488 nm,561 nm,640 nm_Seq0000.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug1/dose1/grn_d6_24hr_posttx_WellA01_Channel_405nm_488nm_561nm_640nm_Seq0000.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellN23_Channel405 nm,488 nm,561 nm,640 nm_Seq0313.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug11/dose7/grn_d6_24hr_posttx_WellN23_Channel_405nm_488nm_561nm_640nm_Seq0313.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellL05_Channel405 nm,488 nm,561 nm,640 nm_Seq0283.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug7/dose6/grn_d6_24hr_posttx_WellL05_Channel_405nm_488nm_561nm_640nm_Seq0283.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellF09_Channel405 nm,488 nm,561 nm,640 nm_Seq0135.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug9/dose3/grn_d6_24hr_posttx_WellF09_Channel_405nm_488nm_561nm_640nm_Seq0135.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellI08_Channel405 nm,488 nm,561 nm,640 nm_Seq0199.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug2/dose5/grn_d6_24hr_posttx_WellI08_Channel_405nm_488nm_561nm_640nm_Seq0199.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellK03_Channel405 nm,488 nm,561 nm,640 nm_Seq0242.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug1/dose6/grn_d6_24hr_posttx_WellK03_Channel_405nm_488nm_561nm_640nm_Seq0242.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellA10_Channel405 nm,488 nm,561 nm,640 nm_Seq0009.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug4/dose1/grn_d6_24hr_posttx_WellA10_Channel_405nm_488nm_561nm_640nm_Seq0009.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellN18_Channel405 nm,488 nm,561 nm,640 nm_Seq0318.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug12/dose7/grn_d6_24hr_posttx_WellN18_Channel_405nm_488nm_561nm_640nm_Seq0318.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellO11_Channel405 nm,488 nm,561 nm,640 nm_Seq0346.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug3/dose8/grn_d6_24hr_posttx_WellO11_Channel_405nm_488nm_561nm_640nm_Seq0346.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellM12_Channel405 nm,488 nm,561 nm,640 nm_Seq0299.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug4/dose7/grn_d6_24hr_posttx_WellM12_Channel_405nm_488nm_561nm_640nm_Seq0299.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellI22_Channel405 nm,488 nm,561 nm,640 nm_Seq0213.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug6/dose5/grn_d6_24hr_posttx_WellI22_Channel_405nm_488nm_561nm_640nm_Seq0213.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellP21_Channel405 nm,488 nm,561 nm,640 nm_Seq0363.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug11/dose8/grn_d6_24hr_posttx_WellP21_Channel_405nm_488nm_561nm_640nm_Seq0363.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellJ24_Channel405 nm,488 nm,561 nm,640 nm_Seq0216.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug12/dose5/grn_d6_24hr_posttx_WellJ24_Channel_405nm_488nm_561nm_640nm_Seq0216.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellO19_Channel405 nm,488 nm,561 nm,640 nm_Seq0354.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug5/dose8/grn_d6_24hr_posttx_WellO19_Channel_405nm_488nm_561nm_640nm_Seq0354.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellH21_Channel405 nm,488 nm,561 nm,640 nm_Seq0171.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug11/dose4/grn_d6_24hr_posttx_WellH21_Channel_405nm_488nm_561nm_640nm_Seq0171.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellP02_Channel405 nm,488 nm,561 nm,640 nm_Seq0382.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug8/dose8/grn_d6_24hr_posttx_WellP02_Channel_405nm_488nm_561nm_640nm_Seq0382.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellC24_Channel405 nm,488 nm,561 nm,640 nm_Seq0071.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug6/dose2/grn_d6_24hr_posttx_WellC24_Channel_405nm_488nm_561nm_640nm_Seq0071.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellL23_Channel405 nm,488 nm,561 nm,640 nm_Seq0265.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug11/dose6/grn_d6_24hr_posttx_WellL23_Channel_405nm_488nm_561nm_640nm_Seq0265.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellK06_Channel405 nm,488 nm,561 nm,640 nm_Seq0245.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug2/dose6/grn_d6_24hr_posttx_WellK06_Channel_405nm_488nm_561nm_640nm_Seq0245.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellG08_Channel405 nm,488 nm,561 nm,640 nm_Seq0151.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug2/dose4/grn_d6_24hr_posttx_WellG08_Channel_405nm_488nm_561nm_640nm_Seq0151.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellH02_Channel405 nm,488 nm,561 nm,640 nm_Seq0190.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug8/dose4/grn_d6_24hr_posttx_WellH02_Channel_405nm_488nm_561nm_640nm_Seq0190.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellM03_Channel405 nm,488 nm,561 nm,640 nm_Seq0290.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug1/dose7/grn_d6_24hr_posttx_WellM03_Channel_405nm_488nm_561nm_640nm_Seq0290.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellF15_Channel405 nm,488 nm,561 nm,640 nm_Seq0129.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug9/dose3/grn_d6_24hr_posttx_WellF15_Channel_405nm_488nm_561nm_640nm_Seq0129.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellN19_Channel405 nm,488 nm,561 nm,640 nm_Seq0317.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug11/dose7/grn_d6_24hr_posttx_WellN19_Channel_405nm_488nm_561nm_640nm_Seq0317.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellC13_Channel405 nm,488 nm,561 nm,640 nm_Seq0060.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug3/dose2/grn_d6_24hr_posttx_WellC13_Channel_405nm_488nm_561nm_640nm_Seq0060.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellL14_Channel405 nm,488 nm,561 nm,640 nm_Seq0274.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug10/dose6/grn_d6_24hr_posttx_WellL14_Channel_405nm_488nm_561nm_640nm_Seq0274.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellE06_Channel405 nm,488 nm,561 nm,640 nm_Seq0101.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug2/dose3/grn_d6_24hr_posttx_WellE06_Channel_405nm_488nm_561nm_640nm_Seq0101.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellA04_Channel405 nm,488 nm,561 nm,640 nm_Seq0003.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug2/dose1/grn_d6_24hr_posttx_WellA04_Channel_405nm_488nm_561nm_640nm_Seq0003.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellI15_Channel405 nm,488 nm,561 nm,640 nm_Seq0206.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug3/dose5/grn_d6_24hr_posttx_WellI15_Channel_405nm_488nm_561nm_640nm_Seq0206.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellM17_Channel405 nm,488 nm,561 nm,640 nm_Seq0304.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug5/dose7/grn_d6_24hr_posttx_WellM17_Channel_405nm_488nm_561nm_640nm_Seq0304.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellN15_Channel405 nm,488 nm,561 nm,640 nm_Seq0321.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug9/dose7/grn_d6_24hr_posttx_WellN15_Channel_405nm_488nm_561nm_640nm_Seq0321.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellJ17_Channel405 nm,488 nm,561 nm,640 nm_Seq0223.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug11/dose5/grn_d6_24hr_posttx_WellJ17_Channel_405nm_488nm_561nm_640nm_Seq0223.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellD11_Channel405 nm,488 nm,561 nm,640 nm_Seq0085.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug9/dose2/grn_d6_24hr_posttx_WellD11_Channel_405nm_488nm_561nm_640nm_Seq0085.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellE03_Channel405 nm,488 nm,561 nm,640 nm_Seq0098.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug1/dose3/grn_d6_24hr_posttx_WellE03_Channel_405nm_488nm_561nm_640nm_Seq0098.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellK20_Channel405 nm,488 nm,561 nm,640 nm_Seq0259.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug6/dose6/grn_d6_24hr_posttx_WellK20_Channel_405nm_488nm_561nm_640nm_Seq0259.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellL10_Channel405 nm,488 nm,561 nm,640 nm_Seq0278.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug10/dose6/grn_d6_24hr_posttx_WellL10_Channel_405nm_488nm_561nm_640nm_Seq0278.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellD14_Channel405 nm,488 nm,561 nm,640 nm_Seq0082.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug10/dose2/grn_d6_24hr_posttx_WellD14_Channel_405nm_488nm_561nm_640nm_Seq0082.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellN10_Channel405 nm,488 nm,561 nm,640 nm_Seq0326.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug10/dose7/grn_d6_24hr_posttx_WellN10_Channel_405nm_488nm_561nm_640nm_Seq0326.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellP24_Channel405 nm,488 nm,561 nm,640 nm_Seq0360.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug12/dose8/grn_d6_24hr_posttx_WellP24_Channel_405nm_488nm_561nm_640nm_Seq0360.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellE21_Channel405 nm,488 nm,561 nm,640 nm_Seq0116.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug5/dose3/grn_d6_24hr_posttx_WellE21_Channel_405nm_488nm_561nm_640nm_Seq0116.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellC16_Channel405 nm,488 nm,561 nm,640 nm_Seq0063.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug4/dose2/grn_d6_24hr_posttx_WellC16_Channel_405nm_488nm_561nm_640nm_Seq0063.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellL11_Channel405 nm,488 nm,561 nm,640 nm_Seq0277.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug9/dose6/grn_d6_24hr_posttx_WellL11_Channel_405nm_488nm_561nm_640nm_Seq0277.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellM06_Channel405 nm,488 nm,561 nm,640 nm_Seq0293.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug2/dose7/grn_d6_24hr_posttx_WellM06_Channel_405nm_488nm_561nm_640nm_Seq0293.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellE02_Channel405 nm,488 nm,561 nm,640 nm_Seq0097.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug2/dose3/grn_d6_24hr_posttx_WellE02_Channel_405nm_488nm_561nm_640nm_Seq0097.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellI10_Channel405 nm,488 nm,561 nm,640 nm_Seq0201.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug4/dose5/grn_d6_24hr_posttx_WellI10_Channel_405nm_488nm_561nm_640nm_Seq0201.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellP13_Channel405 nm,488 nm,561 nm,640 nm_Seq0371.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug9/dose8/grn_d6_24hr_posttx_WellP13_Channel_405nm_488nm_561nm_640nm_Seq0371.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellA14_Channel405 nm,488 nm,561 nm,640 nm_Seq0013.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug4/dose1/grn_d6_24hr_posttx_WellA14_Channel_405nm_488nm_561nm_640nm_Seq0013.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellE16_Channel405 nm,488 nm,561 nm,640 nm_Seq0111.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug4/dose3/grn_d6_24hr_posttx_WellE16_Channel_405nm_488nm_561nm_640nm_Seq0111.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellB21_Channel405 nm,488 nm,561 nm,640 nm_Seq0027.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug11/dose1/grn_d6_24hr_posttx_WellB21_Channel_405nm_488nm_561nm_640nm_Seq0027.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellD09_Channel405 nm,488 nm,561 nm,640 nm_Seq0087.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug9/dose2/grn_d6_24hr_posttx_WellD09_Channel_405nm_488nm_561nm_640nm_Seq0087.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellD01_Channel405 nm,488 nm,561 nm,640 nm_Seq0095.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug7/dose2/grn_d6_24hr_posttx_WellD01_Channel_405nm_488nm_561nm_640nm_Seq0095.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellJ07_Channel405 nm,488 nm,561 nm,640 nm_Seq0233.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug7/dose5/grn_d6_24hr_posttx_WellJ07_Channel_405nm_488nm_561nm_640nm_Seq0233.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellN05_Channel405 nm,488 nm,561 nm,640 nm_Seq0331.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug7/dose7/grn_d6_24hr_posttx_WellN05_Channel_405nm_488nm_561nm_640nm_Seq0331.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellH07_Channel405 nm,488 nm,561 nm,640 nm_Seq0185.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug7/dose4/grn_d6_24hr_posttx_WellH07_Channel_405nm_488nm_561nm_640nm_Seq0185.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellG23_Channel405 nm,488 nm,561 nm,640 nm_Seq0166.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug5/dose4/grn_d6_24hr_posttx_WellG23_Channel_405nm_488nm_561nm_640nm_Seq0166.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellD22_Channel405 nm,488 nm,561 nm,640 nm_Seq0074.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug12/dose2/grn_d6_24hr_posttx_WellD22_Channel_405nm_488nm_561nm_640nm_Seq0074.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellC07_Channel405 nm,488 nm,561 nm,640 nm_Seq0054.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug1/dose2/grn_d6_24hr_posttx_WellC07_Channel_405nm_488nm_561nm_640nm_Seq0054.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellB20_Channel405 nm,488 nm,561 nm,640 nm_Seq0028.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug12/dose1/grn_d6_24hr_posttx_WellB20_Channel_405nm_488nm_561nm_640nm_Seq0028.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellD04_Channel405 nm,488 nm,561 nm,640 nm_Seq0092.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug8/dose2/grn_d6_24hr_posttx_WellD04_Channel_405nm_488nm_561nm_640nm_Seq0092.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellF11_Channel405 nm,488 nm,561 nm,640 nm_Seq0133.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug9/dose3/grn_d6_24hr_posttx_WellF11_Channel_405nm_488nm_561nm_640nm_Seq0133.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellD08_Channel405 nm,488 nm,561 nm,640 nm_Seq0088.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug8/dose2/grn_d6_24hr_posttx_WellD08_Channel_405nm_488nm_561nm_640nm_Seq0088.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellG19_Channel405 nm,488 nm,561 nm,640 nm_Seq0162.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug5/dose4/grn_d6_24hr_posttx_WellG19_Channel_405nm_488nm_561nm_640nm_Seq0162.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellB01_Channel405 nm,488 nm,561 nm,640 nm_Seq0047.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug7/dose1/grn_d6_24hr_posttx_WellB01_Channel_405nm_488nm_561nm_640nm_Seq0047.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellF13_Channel405 nm,488 nm,561 nm,640 nm_Seq0131.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug9/dose3/grn_d6_24hr_posttx_WellF13_Channel_405nm_488nm_561nm_640nm_Seq0131.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellD06_Channel405 nm,488 nm,561 nm,640 nm_Seq0090.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug8/dose2/grn_d6_24hr_posttx_WellD06_Channel_405nm_488nm_561nm_640nm_Seq0090.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellN02_Channel405 nm,488 nm,561 nm,640 nm_Seq0334.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug8/dose7/grn_d6_24hr_posttx_WellN02_Channel_405nm_488nm_561nm_640nm_Seq0334.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellF24_Channel405 nm,488 nm,561 nm,640 nm_Seq0120.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug12/dose3/grn_d6_24hr_posttx_WellF24_Channel_405nm_488nm_561nm_640nm_Seq0120.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellB03_Channel405 nm,488 nm,561 nm,640 nm_Seq0045.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug7/dose1/grn_d6_24hr_posttx_WellB03_Channel_405nm_488nm_561nm_640nm_Seq0045.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellI03_Channel405 nm,488 nm,561 nm,640 nm_Seq0194.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug1/dose5/grn_d6_24hr_posttx_WellI03_Channel_405nm_488nm_561nm_640nm_Seq0194.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellC11_Channel405 nm,488 nm,561 nm,640 nm_Seq0058.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug3/dose2/grn_d6_24hr_posttx_WellC11_Channel_405nm_488nm_561nm_640nm_Seq0058.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellC22_Channel405 nm,488 nm,561 nm,640 nm_Seq0069.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug6/dose2/grn_d6_24hr_posttx_WellC22_Channel_405nm_488nm_561nm_640nm_Seq0069.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellH04_Channel405 nm,488 nm,561 nm,640 nm_Seq0188.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug8/dose4/grn_d6_24hr_posttx_WellH04_Channel_405nm_488nm_561nm_640nm_Seq0188.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellB06_Channel405 nm,488 nm,561 nm,640 nm_Seq0042.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug8/dose1/grn_d6_24hr_posttx_WellB06_Channel_405nm_488nm_561nm_640nm_Seq0042.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellB23_Channel405 nm,488 nm,561 nm,640 nm_Seq0025.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug11/dose1/grn_d6_24hr_posttx_WellB23_Channel_405nm_488nm_561nm_640nm_Seq0025.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellF04_Channel405 nm,488 nm,561 nm,640 nm_Seq0140.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug8/dose3/grn_d6_24hr_posttx_WellF04_Channel_405nm_488nm_561nm_640nm_Seq0140.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellJ01_Channel405 nm,488 nm,561 nm,640 nm_Seq0239.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug7/dose5/grn_d6_24hr_posttx_WellJ01_Channel_405nm_488nm_561nm_640nm_Seq0239.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellM18_Channel405 nm,488 nm,561 nm,640 nm_Seq0305.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug6/dose7/grn_d6_24hr_posttx_WellM18_Channel_405nm_488nm_561nm_640nm_Seq0305.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellJ18_Channel405 nm,488 nm,561 nm,640 nm_Seq0222.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug12/dose5/grn_d6_24hr_posttx_WellJ18_Channel_405nm_488nm_561nm_640nm_Seq0222.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellB14_Channel405 nm,488 nm,561 nm,640 nm_Seq0034.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug10/dose1/grn_d6_24hr_posttx_WellB14_Channel_405nm_488nm_561nm_640nm_Seq0034.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellD20_Channel405 nm,488 nm,561 nm,640 nm_Seq0076.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug12/dose2/grn_d6_24hr_posttx_WellD20_Channel_405nm_488nm_561nm_640nm_Seq0076.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellJ10_Channel405 nm,488 nm,561 nm,640 nm_Seq0230.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug10/dose5/grn_d6_24hr_posttx_WellJ10_Channel_405nm_488nm_561nm_640nm_Seq0230.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellH05_Channel405 nm,488 nm,561 nm,640 nm_Seq0187.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug7/dose4/grn_d6_24hr_posttx_WellH05_Channel_405nm_488nm_561nm_640nm_Seq0187.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellG21_Channel405 nm,488 nm,561 nm,640 nm_Seq0164.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug5/dose4/grn_d6_24hr_posttx_WellG21_Channel_405nm_488nm_561nm_640nm_Seq0164.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellK14_Channel405 nm,488 nm,561 nm,640 nm_Seq0253.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug4/dose6/grn_d6_24hr_posttx_WellK14_Channel_405nm_488nm_561nm_640nm_Seq0253.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellO16_Channel405 nm,488 nm,561 nm,640 nm_Seq0351.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug4/dose8/grn_d6_24hr_posttx_WellO16_Channel_405nm_488nm_561nm_640nm_Seq0351.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellC10_Channel405 nm,488 nm,561 nm,640 nm_Seq0057.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug4/dose2/grn_d6_24hr_posttx_WellC10_Channel_405nm_488nm_561nm_640nm_Seq0057.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellG12_Channel405 nm,488 nm,561 nm,640 nm_Seq0155.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug4/dose4/grn_d6_24hr_posttx_WellG12_Channel_405nm_488nm_561nm_640nm_Seq0155.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellJ23_Channel405 nm,488 nm,561 nm,640 nm_Seq0217.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug11/dose5/grn_d6_24hr_posttx_WellJ23_Channel_405nm_488nm_561nm_640nm_Seq0217.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellN21_Channel405 nm,488 nm,561 nm,640 nm_Seq0315.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug11/dose7/grn_d6_24hr_posttx_WellN21_Channel_405nm_488nm_561nm_640nm_Seq0315.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellC23_Channel405 nm,488 nm,561 nm,640 nm_Seq0070.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug5/dose2/grn_d6_24hr_posttx_WellC23_Channel_405nm_488nm_561nm_640nm_Seq0070.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellL24_Channel405 nm,488 nm,561 nm,640 nm_Seq0264.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug12/dose6/grn_d6_24hr_posttx_WellL24_Channel_405nm_488nm_561nm_640nm_Seq0264.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellN12_Channel405 nm,488 nm,561 nm,640 nm_Seq0324.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug10/dose7/grn_d6_24hr_posttx_WellN12_Channel_405nm_488nm_561nm_640nm_Seq0324.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellD16_Channel405 nm,488 nm,561 nm,640 nm_Seq0080.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug10/dose2/grn_d6_24hr_posttx_WellD16_Channel_405nm_488nm_561nm_640nm_Seq0080.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellO21_Channel405 nm,488 nm,561 nm,640 nm_Seq0356.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug5/dose8/grn_d6_24hr_posttx_WellO21_Channel_405nm_488nm_561nm_640nm_Seq0356.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellC01_Channel405 nm,488 nm,561 nm,640 nm_Seq0048.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug1/dose2/grn_d6_24hr_posttx_WellC01_Channel_405nm_488nm_561nm_640nm_Seq0048.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellP11_Channel405 nm,488 nm,561 nm,640 nm_Seq0373.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug9/dose8/grn_d6_24hr_posttx_WellP11_Channel_405nm_488nm_561nm_640nm_Seq0373.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellI12_Channel405 nm,488 nm,561 nm,640 nm_Seq0203.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug4/dose5/grn_d6_24hr_posttx_WellI12_Channel_405nm_488nm_561nm_640nm_Seq0203.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellH19_Channel405 nm,488 nm,561 nm,640 nm_Seq0173.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug11/dose4/grn_d6_24hr_posttx_WellH19_Channel_405nm_488nm_561nm_640nm_Seq0173.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellM04_Channel405 nm,488 nm,561 nm,640 nm_Seq0291.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug2/dose7/grn_d6_24hr_posttx_WellM04_Channel_405nm_488nm_561nm_640nm_Seq0291.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellD07_Channel405 nm,488 nm,561 nm,640 nm_Seq0089.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug7/dose2/grn_d6_24hr_posttx_WellD07_Channel_405nm_488nm_561nm_640nm_Seq0089.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellC14_Channel405 nm,488 nm,561 nm,640 nm_Seq0061.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug4/dose2/grn_d6_24hr_posttx_WellC14_Channel_405nm_488nm_561nm_640nm_Seq0061.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellL13_Channel405 nm,488 nm,561 nm,640 nm_Seq0275.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug9/dose6/grn_d6_24hr_posttx_WellL13_Channel_405nm_488nm_561nm_640nm_Seq0275.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellJ11_Channel405 nm,488 nm,561 nm,640 nm_Seq0229.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug9/dose5/grn_d6_24hr_posttx_WellJ11_Channel_405nm_488nm_561nm_640nm_Seq0229.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellO01_Channel405 nm,488 nm,561 nm,640 nm_Seq0336.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug1/dose8/grn_d6_24hr_posttx_WellO01_Channel_405nm_488nm_561nm_640nm_Seq0336.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellL16_Channel405 nm,488 nm,561 nm,640 nm_Seq0272.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug10/dose6/grn_d6_24hr_posttx_WellL16_Channel_405nm_488nm_561nm_640nm_Seq0272.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellJ22_Channel405 nm,488 nm,561 nm,640 nm_Seq0218.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug12/dose5/grn_d6_24hr_posttx_WellJ22_Channel_405nm_488nm_561nm_640nm_Seq0218.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellA20_Channel405 nm,488 nm,561 nm,640 nm_Seq0019.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug6/dose1/grn_d6_24hr_posttx_WellA20_Channel_405nm_488nm_561nm_640nm_Seq0019.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellN24_Channel405 nm,488 nm,561 nm,640 nm_Seq0312.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug12/dose7/grn_d6_24hr_posttx_WellN24_Channel_405nm_488nm_561nm_640nm_Seq0312.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellJ08_Channel405 nm,488 nm,561 nm,640 nm_Seq0232.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug8/dose5/grn_d6_24hr_posttx_WellJ08_Channel_405nm_488nm_561nm_640nm_Seq0232.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellH08_Channel405 nm,488 nm,561 nm,640 nm_Seq0184.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug8/dose4/grn_d6_24hr_posttx_WellH08_Channel_405nm_488nm_561nm_640nm_Seq0184.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellG02_Channel405 nm,488 nm,561 nm,640 nm_Seq0145.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug2/dose4/grn_d6_24hr_posttx_WellG02_Channel_405nm_488nm_561nm_640nm_Seq0145.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellO06_Channel405 nm,488 nm,561 nm,640 nm_Seq0341.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug2/dose8/grn_d6_24hr_posttx_WellO06_Channel_405nm_488nm_561nm_640nm_Seq0341.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellK04_Channel405 nm,488 nm,561 nm,640 nm_Seq0243.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug2/dose6/grn_d6_24hr_posttx_WellK04_Channel_405nm_488nm_561nm_640nm_Seq0243.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellC08_Channel405 nm,488 nm,561 nm,640 nm_Seq0055.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug2/dose2/grn_d6_24hr_posttx_WellC08_Channel_405nm_488nm_561nm_640nm_Seq0055.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellD13_Channel405 nm,488 nm,561 nm,640 nm_Seq0083.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug9/dose2/grn_d6_24hr_posttx_WellD13_Channel_405nm_488nm_561nm_640nm_Seq0083.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellJ15_Channel405 nm,488 nm,561 nm,640 nm_Seq0225.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug9/dose5/grn_d6_24hr_posttx_WellJ15_Channel_405nm_488nm_561nm_640nm_Seq0225.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellL21_Channel405 nm,488 nm,561 nm,640 nm_Seq0267.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug11/dose6/grn_d6_24hr_posttx_WellL21_Channel_405nm_488nm_561nm_640nm_Seq0267.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellP05_Channel405 nm,488 nm,561 nm,640 nm_Seq0379.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug7/dose8/grn_d6_24hr_posttx_WellP05_Channel_405nm_488nm_561nm_640nm_Seq0379.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellL02_Channel405 nm,488 nm,561 nm,640 nm_Seq0286.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug8/dose6/grn_d6_24hr_posttx_WellL02_Channel_405nm_488nm_561nm_640nm_Seq0286.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellP23_Channel405 nm,488 nm,561 nm,640 nm_Seq0361.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug11/dose8/grn_d6_24hr_posttx_WellP23_Channel_405nm_488nm_561nm_640nm_Seq0361.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellI20_Channel405 nm,488 nm,561 nm,640 nm_Seq0211.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug6/dose5/grn_d6_24hr_posttx_WellI20_Channel_405nm_488nm_561nm_640nm_Seq0211.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellA06_Channel405 nm,488 nm,561 nm,640 nm_Seq0005.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug2/dose1/grn_d6_24hr_posttx_WellA06_Channel_405nm_488nm_561nm_640nm_Seq0005.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellG06_Channel405 nm,488 nm,561 nm,640 nm_Seq0149.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug2/dose4/grn_d6_24hr_posttx_WellG06_Channel_405nm_488nm_561nm_640nm_Seq0149.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellE19_Channel405 nm,488 nm,561 nm,640 nm_Seq0114.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug5/dose3/grn_d6_24hr_posttx_WellE19_Channel_405nm_488nm_561nm_640nm_Seq0114.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellM15_Channel405 nm,488 nm,561 nm,640 nm_Seq0302.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug3/dose7/grn_d6_24hr_posttx_WellM15_Channel_405nm_488nm_561nm_640nm_Seq0302.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellP14_Channel405 nm,488 nm,561 nm,640 nm_Seq0370.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug10/dose8/grn_d6_24hr_posttx_WellP14_Channel_405nm_488nm_561nm_640nm_Seq0370.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellE11_Channel405 nm,488 nm,561 nm,640 nm_Seq0106.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug3/dose3/grn_d6_24hr_posttx_WellE11_Channel_405nm_488nm_561nm_640nm_Seq0106.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellA03_Channel405 nm,488 nm,561 nm,640 nm_Seq0002.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug1/dose1/grn_d6_24hr_posttx_WellA03_Channel_405nm_488nm_561nm_640nm_Seq0002.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellK10_Channel405 nm,488 nm,561 nm,640 nm_Seq0249.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug4/dose6/grn_d6_24hr_posttx_WellK10_Channel_405nm_488nm_561nm_640nm_Seq0249.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellP19_Channel405 nm,488 nm,561 nm,640 nm_Seq0365.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug11/dose8/grn_d6_24hr_posttx_WellP19_Channel_405nm_488nm_561nm_640nm_Seq0365.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellL20_Channel405 nm,488 nm,561 nm,640 nm_Seq0268.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug12/dose6/grn_d6_24hr_posttx_WellL20_Channel_405nm_488nm_561nm_640nm_Seq0268.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellE04_Channel405 nm,488 nm,561 nm,640 nm_Seq0099.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug2/dose3/grn_d6_24hr_posttx_WellE04_Channel_405nm_488nm_561nm_640nm_Seq0099.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellK01_Channel405 nm,488 nm,561 nm,640 nm_Seq0240.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug1/dose6/grn_d6_24hr_posttx_WellK01_Channel_405nm_488nm_561nm_640nm_Seq0240.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellL07_Channel405 nm,488 nm,561 nm,640 nm_Seq0281.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug7/dose6/grn_d6_24hr_posttx_WellL07_Channel_405nm_488nm_561nm_640nm_Seq0281.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellJ05_Channel405 nm,488 nm,561 nm,640 nm_Seq0235.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug7/dose5/grn_d6_24hr_posttx_WellJ05_Channel_405nm_488nm_561nm_640nm_Seq0235.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellH10_Channel405 nm,488 nm,561 nm,640 nm_Seq0182.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug10/dose4/grn_d6_24hr_posttx_WellH10_Channel_405nm_488nm_561nm_640nm_Seq0182.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellD03_Channel405 nm,488 nm,561 nm,640 nm_Seq0093.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug7/dose2/grn_d6_24hr_posttx_WellD03_Channel_405nm_488nm_561nm_640nm_Seq0093.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellG07_Channel405 nm,488 nm,561 nm,640 nm_Seq0150.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug1/dose4/grn_d6_24hr_posttx_WellG07_Channel_405nm_488nm_561nm_640nm_Seq0150.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellC05_Channel405 nm,488 nm,561 nm,640 nm_Seq0052.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug1/dose2/grn_d6_24hr_posttx_WellC05_Channel_405nm_488nm_561nm_640nm_Seq0052.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellP15_Channel405 nm,488 nm,561 nm,640 nm_Seq0369.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug9/dose8/grn_d6_24hr_posttx_WellP15_Channel_405nm_488nm_561nm_640nm_Seq0369.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellB10_Channel405 nm,488 nm,561 nm,640 nm_Seq0038.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug10/dose1/grn_d6_24hr_posttx_WellB10_Channel_405nm_488nm_561nm_640nm_Seq0038.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellA16_Channel405 nm,488 nm,561 nm,640 nm_Seq0015.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug4/dose1/grn_d6_24hr_posttx_WellA16_Channel_405nm_488nm_561nm_640nm_Seq0015.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellF21_Channel405 nm,488 nm,561 nm,640 nm_Seq0123.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug11/dose3/grn_d6_24hr_posttx_WellF21_Channel_405nm_488nm_561nm_640nm_Seq0123.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellI06_Channel405 nm,488 nm,561 nm,640 nm_Seq0197.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug2/dose5/grn_d6_24hr_posttx_WellI06_Channel_405nm_488nm_561nm_640nm_Seq0197.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellG16_Channel405 nm,488 nm,561 nm,640 nm_Seq0159.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug4/dose4/grn_d6_24hr_posttx_WellG16_Channel_405nm_488nm_561nm_640nm_Seq0159.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellE09_Channel405 nm,488 nm,561 nm,640 nm_Seq0104.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug3/dose3/grn_d6_24hr_posttx_WellE09_Channel_405nm_488nm_561nm_640nm_Seq0104.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellA13_Channel405 nm,488 nm,561 nm,640 nm_Seq0012.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug3/dose1/grn_d6_24hr_posttx_WellA13_Channel_405nm_488nm_561nm_640nm_Seq0012.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellM09_Channel405 nm,488 nm,561 nm,640 nm_Seq0296.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug3/dose7/grn_d6_24hr_posttx_WellM09_Channel_405nm_488nm_561nm_640nm_Seq0296.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellF01_Channel405 nm,488 nm,561 nm,640 nm_Seq0143.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug7/dose3/grn_d6_24hr_posttx_WellF01_Channel_405nm_488nm_561nm_640nm_Seq0143.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellC19_Channel405 nm,488 nm,561 nm,640 nm_Seq0066.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug5/dose2/grn_d6_24hr_posttx_WellC19_Channel_405nm_488nm_561nm_640nm_Seq0066.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellP09_Channel405 nm,488 nm,561 nm,640 nm_Seq0375.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug9/dose8/grn_d6_24hr_posttx_WellP09_Channel_405nm_488nm_561nm_640nm_Seq0375.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellK11_Channel405 nm,488 nm,561 nm,640 nm_Seq0250.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug3/dose6/grn_d6_24hr_posttx_WellK11_Channel_405nm_488nm_561nm_640nm_Seq0250.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellI07_Channel405 nm,488 nm,561 nm,640 nm_Seq0198.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug1/dose5/grn_d6_24hr_posttx_WellI07_Channel_405nm_488nm_561nm_640nm_Seq0198.nd2
# ...
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellB08_Channel405 nm,488 nm,561 nm,640 nm_Seq0040.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug8/dose1/grn_d6_24hr_posttx_WellB08_Channel_405nm_488nm_561nm_640nm_Seq0040.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellL15_Channel405 nm,488 nm,561 nm,640 nm_Seq0273.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug9/dose6/grn_d6_24hr_posttx_WellL15_Channel_405nm_488nm_561nm_640nm_Seq0273.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellJ21_Channel405 nm,488 nm,561 nm,640 nm_Seq0219.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug11/dose5/grn_d6_24hr_posttx_WellJ21_Channel_405nm_488nm_561nm_640nm_Seq0219.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellO18_Channel405 nm,488 nm,561 nm,640 nm_Seq0353.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug6/dose8/grn_d6_24hr_posttx_WellO18_Channel_405nm_488nm_561nm_640nm_Seq0353.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellP20_Channel405 nm,488 nm,561 nm,640 nm_Seq0364.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug12/dose8/grn_d6_24hr_posttx_WellP20_Channel_405nm_488nm_561nm_640nm_Seq0364.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellL19_Channel405 nm,488 nm,561 nm,640 nm_Seq0269.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug11/dose6/grn_d6_24hr_posttx_WellL19_Channel_405nm_488nm_561nm_640nm_Seq0269.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellI23_Channel405 nm,488 nm,561 nm,640 nm_Seq0214.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug5/dose5/grn_d6_24hr_posttx_WellI23_Channel_405nm_488nm_561nm_640nm_Seq0214.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellO05_Channel405 nm,488 nm,561 nm,640 nm_Seq0340.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug1/dose8/grn_d6_24hr_posttx_WellO05_Channel_405nm_488nm_561nm_640nm_Seq0340.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellD10_Channel405 nm,488 nm,561 nm,640 nm_Seq0086.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug10/dose2/grn_d6_24hr_posttx_WellD10_Channel_405nm_488nm_561nm_640nm_Seq0086.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellN14_Channel405 nm,488 nm,561 nm,640 nm_Seq0322.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug10/dose7/grn_d6_24hr_posttx_WellN14_Channel_405nm_488nm_561nm_640nm_Seq0322.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellG01_Channel405 nm,488 nm,561 nm,640 nm_Seq0144.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug1/dose4/grn_d6_24hr_posttx_WellG01_Channel_405nm_488nm_561nm_640nm_Seq0144.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellO23_Channel405 nm,488 nm,561 nm,640 nm_Seq0358.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug5/dose8/grn_d6_24hr_posttx_WellO23_Channel_405nm_488nm_561nm_640nm_Seq0358.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellP03_Channel405 nm,488 nm,561 nm,640 nm_Seq0381.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug7/dose8/grn_d6_24hr_posttx_WellP03_Channel_405nm_488nm_561nm_640nm_Seq0381.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellG09_Channel405 nm,488 nm,561 nm,640 nm_Seq0152.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug3/dose4/grn_d6_24hr_posttx_WellG09_Channel_405nm_488nm_561nm_640nm_Seq0152.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellJ16_Channel405 nm,488 nm,561 nm,640 nm_Seq0224.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug10/dose5/grn_d6_24hr_posttx_WellJ16_Channel_405nm_488nm_561nm_640nm_Seq0224.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellL22_Channel405 nm,488 nm,561 nm,640 nm_Seq0266.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug12/dose6/grn_d6_24hr_posttx_WellL22_Channel_405nm_488nm_561nm_640nm_Seq0266.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellK07_Channel405 nm,488 nm,561 nm,640 nm_Seq0246.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug1/dose6/grn_d6_24hr_posttx_WellK07_Channel_405nm_488nm_561nm_640nm_Seq0246.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellO10_Channel405 nm,488 nm,561 nm,640 nm_Seq0345.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug4/dose8/grn_d6_24hr_posttx_WellO10_Channel_405nm_488nm_561nm_640nm_Seq0345.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellP06_Channel405 nm,488 nm,561 nm,640 nm_Seq0378.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug8/dose8/grn_d6_24hr_posttx_WellP06_Channel_405nm_488nm_561nm_640nm_Seq0378.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellH20_Channel405 nm,488 nm,561 nm,640 nm_Seq0172.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug12/dose4/grn_d6_24hr_posttx_WellH20_Channel_405nm_488nm_561nm_640nm_Seq0172.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellL01_Channel405 nm,488 nm,561 nm,640 nm_Seq0287.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug7/dose6/grn_d6_24hr_posttx_WellL01_Channel_405nm_488nm_561nm_640nm_Seq0287.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellA05_Channel405 nm,488 nm,561 nm,640 nm_Seq0004.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug1/dose1/grn_d6_24hr_posttx_WellA05_Channel_405nm_488nm_561nm_640nm_Seq0004.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellE12_Channel405 nm,488 nm,561 nm,640 nm_Seq0107.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug4/dose3/grn_d6_24hr_posttx_WellE12_Channel_405nm_488nm_561nm_640nm_Seq0107.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellG05_Channel405 nm,488 nm,561 nm,640 nm_Seq0148.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug1/dose4/grn_d6_24hr_posttx_WellG05_Channel_405nm_488nm_561nm_640nm_Seq0148.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellM16_Channel405 nm,488 nm,561 nm,640 nm_Seq0303.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug4/dose7/grn_d6_24hr_posttx_WellM16_Channel_405nm_488nm_561nm_640nm_Seq0303.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellA18_Channel405 nm,488 nm,561 nm,640 nm_Seq0017.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug6/dose1/grn_d6_24hr_posttx_WellA18_Channel_405nm_488nm_561nm_640nm_Seq0017.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellC17_Channel405 nm,488 nm,561 nm,640 nm_Seq0064.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug5/dose2/grn_d6_24hr_posttx_WellC17_Channel_405nm_488nm_561nm_640nm_Seq0064.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellE24_Channel405 nm,488 nm,561 nm,640 nm_Seq0119.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug6/dose3/grn_d6_24hr_posttx_WellE24_Channel_405nm_488nm_561nm_640nm_Seq0119.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellP07_Channel405 nm,488 nm,561 nm,640 nm_Seq0377.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug7/dose8/grn_d6_24hr_posttx_WellP07_Channel_405nm_488nm_561nm_640nm_Seq0377.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellM07_Channel405 nm,488 nm,561 nm,640 nm_Seq0294.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug1/dose7/grn_d6_24hr_posttx_WellM07_Channel_405nm_488nm_561nm_640nm_Seq0294.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellK02_Channel405 nm,488 nm,561 nm,640 nm_Seq0241.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug2/dose6/grn_d6_24hr_posttx_WellK02_Channel_405nm_488nm_561nm_640nm_Seq0241.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellE13_Channel405 nm,488 nm,561 nm,640 nm_Seq0108.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug3/dose3/grn_d6_24hr_posttx_WellE13_Channel_405nm_488nm_561nm_640nm_Seq0108.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellA19_Channel405 nm,488 nm,561 nm,640 nm_Seq0018.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug5/dose1/grn_d6_24hr_posttx_WellA19_Channel_405nm_488nm_561nm_640nm_Seq0018.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellG04_Channel405 nm,488 nm,561 nm,640 nm_Seq0147.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug2/dose4/grn_d6_24hr_posttx_WellG04_Channel_405nm_488nm_561nm_640nm_Seq0147.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellF08_Channel405 nm,488 nm,561 nm,640 nm_Seq0136.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug8/dose3/grn_d6_24hr_posttx_WellF08_Channel_405nm_488nm_561nm_640nm_Seq0136.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellK17_Channel405 nm,488 nm,561 nm,640 nm_Seq0256.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug5/dose6/grn_d6_24hr_posttx_WellK17_Channel_405nm_488nm_561nm_640nm_Seq0256.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellJ06_Channel405 nm,488 nm,561 nm,640 nm_Seq0234.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug8/dose5/grn_d6_24hr_posttx_WellJ06_Channel_405nm_488nm_561nm_640nm_Seq0234.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellD18_Channel405 nm,488 nm,561 nm,640 nm_Seq0078.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug12/dose2/grn_d6_24hr_posttx_WellD18_Channel_405nm_488nm_561nm_640nm_Seq0078.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellB17_Channel405 nm,488 nm,561 nm,640 nm_Seq0031.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug11/dose1/grn_d6_24hr_posttx_WellB17_Channel_405nm_488nm_561nm_640nm_Seq0031.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellC06_Channel405 nm,488 nm,561 nm,640 nm_Seq0053.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug2/dose2/grn_d6_24hr_posttx_WellC06_Channel_405nm_488nm_561nm_640nm_Seq0053.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellD23_Channel405 nm,488 nm,561 nm,640 nm_Seq0073.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug11/dose2/grn_d6_24hr_posttx_WellD23_Channel_405nm_488nm_561nm_640nm_Seq0073.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellP16_Channel405 nm,488 nm,561 nm,640 nm_Seq0368.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug10/dose8/grn_d6_24hr_posttx_WellP16_Channel_405nm_488nm_561nm_640nm_Seq0368.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellA15_Channel405 nm,488 nm,561 nm,640 nm_Seq0014.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug3/dose1/grn_d6_24hr_posttx_WellA15_Channel_405nm_488nm_561nm_640nm_Seq0014.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellA08_Channel405 nm,488 nm,561 nm,640 nm_Seq0007.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug2/dose1/grn_d6_24hr_posttx_WellA08_Channel_405nm_488nm_561nm_640nm_Seq0007.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellI05_Channel405 nm,488 nm,561 nm,640 nm_Seq0196.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug1/dose5/grn_d6_24hr_posttx_WellI05_Channel_405nm_488nm_561nm_640nm_Seq0196.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellG15_Channel405 nm,488 nm,561 nm,640 nm_Seq0158.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug3/dose4/grn_d6_24hr_posttx_WellG15_Channel_405nm_488nm_561nm_640nm_Seq0158.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellF22_Channel405 nm,488 nm,561 nm,640 nm_Seq0122.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug12/dose3/grn_d6_24hr_posttx_WellF22_Channel_405nm_488nm_561nm_640nm_Seq0122.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellP17_Channel405 nm,488 nm,561 nm,640 nm_Seq0367.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug11/dose8/grn_d6_24hr_posttx_WellP17_Channel_405nm_488nm_561nm_640nm_Seq0367.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellH17_Channel405 nm,488 nm,561 nm,640 nm_Seq0175.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug11/dose4/grn_d6_24hr_posttx_WellH17_Channel_405nm_488nm_561nm_640nm_Seq0175.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellF02_Channel405 nm,488 nm,561 nm,640 nm_Seq0142.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug8/dose3/grn_d6_24hr_posttx_WellF02_Channel_405nm_488nm_561nm_640nm_Seq0142.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellD19_Channel405 nm,488 nm,561 nm,640 nm_Seq0077.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug11/dose2/grn_d6_24hr_posttx_WellD19_Channel_405nm_488nm_561nm_640nm_Seq0077.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellA23_Channel405 nm,488 nm,561 nm,640 nm_Seq0022.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug5/dose1/grn_d6_24hr_posttx_WellA23_Channel_405nm_488nm_561nm_640nm_Seq0022.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellG14_Channel405 nm,488 nm,561 nm,640 nm_Seq0157.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug4/dose4/grn_d6_24hr_posttx_WellG14_Channel_405nm_488nm_561nm_640nm_Seq0157.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellA09_Channel405 nm,488 nm,561 nm,640 nm_Seq0008.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug3/dose1/grn_d6_24hr_posttx_WellA09_Channel_405nm_488nm_561nm_640nm_Seq0008.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellK12_Channel405 nm,488 nm,561 nm,640 nm_Seq0251.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug4/dose6/grn_d6_24hr_posttx_WellK12_Channel_405nm_488nm_561nm_640nm_Seq0251.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellF18_Channel405 nm,488 nm,561 nm,640 nm_Seq0126.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug12/dose3/grn_d6_24hr_posttx_WellF18_Channel_405nm_488nm_561nm_640nm_Seq0126.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellK21_Channel405 nm,488 nm,561 nm,640 nm_Seq0260.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug5/dose6/grn_d6_24hr_posttx_WellK21_Channel_405nm_488nm_561nm_640nm_Seq0260.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellF10_Channel405 nm,488 nm,561 nm,640 nm_Seq0134.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug10/dose3/grn_d6_24hr_posttx_WellF10_Channel_405nm_488nm_561nm_640nm_Seq0134.nd2
# Moved: /Users/uapinyoyingpb/sandbox/ward_test/test_files/grn_d6_24hr_posttx_WellB12_Channel405 nm,488 nm,561 nm,640 nm_Seq0036.nd2
# 	--> /Users/uapinyoyingpb/sandbox/ward_test/test_files/drug10/dose1/grn_d6_24hr_posttx_WellB12_Channel_405nm_488nm_561nm_640nm_Seq0036.nd2
